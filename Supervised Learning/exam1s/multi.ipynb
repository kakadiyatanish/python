# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures

from sklearn.linear_model import LinearRegression

from sklearn.pipeline import Pipeline

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

from sklearn.model_selection import learning_curve

# %%
df = pd.read_csv("RealEstate_HousePrice_Dataset.csv")

# %%
df.head()
# Out:
#    house_id  area_sqft  bedrooms  bathrooms  location_score  age_years  \
# 0    100001       1973         5          4             7.6         23
# 1    100002       1560         3          3             6.3         13
# 2    100003       2071         4          3             5.8          9
# 3    100004       2640         5          3             7.7         12
# 4    100005       1498         3          3             3.8         15
#
#    distance_city_km  lot_size_sqft  has_garage  has_pool  \
# 0              11.9           5220           1         0
# 1              15.8           3882           1         0
# 2              21.1           4488           0         0
# 3               7.9           3614           1         1
# 4              24.0           2663           0         0
#
#    renovation_years_ago  house_price_inr
# 0                     0         40275084
# 1                    13         26812029
# 2                     9         29315677
# 3                     4         47712959
# 4                    15         17724566

# %%
target = "house_price_inr"

# %%
df_clean = df.copy()

print("\n")
print("="*60)
print("PART E : MULTIPLE LINEAR REGRESSION")
print("="*60)

X = df_clean.drop(columns=[target,'house_id'])

y = df_clean[target]

X_train,X_test,y_train,y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

mlr = LinearRegression()

mlr.fit(X_train_scaled,y_train)

pred = mlr.predict(X_test_scaled)

print("MAE :", mean_absolute_error(y_test,pred))
print("RMSE :", np.sqrt(mean_squared_error(y_test,pred)))
print("R2 :", r2_score(y_test,pred))

coef_df = pd.DataFrame({
    'Feature':X.columns,
    'Coefficient':mlr.coef_
})

print("\nFeature Importance:")
print(coef_df.sort_values(
    by='Coefficient',
    ascending=False
))
# Out:
# ============================================================
# PART E : MULTIPLE LINEAR REGRESSION
# ============================================================
# MAE : 2604991.4061556915
# RMSE : 3548650.290480545
# R2 : 0.9177606877509896
#
# Feature Importance:
#                 Feature   Coefficient
# 0             area_sqft  8.745895e+06
# 3        location_score  6.604680e+06
# 1              bedrooms  3.108749e+05
# 2             bathrooms  2.154697e+05
# 6         lot_size_sqft  1.735200e+05
# 8              has_pool  1.351296e+05
# 7            has_garage  4.501288e+04
# 9  renovation_years_ago -1.560784e+05
# 5      distance_city_km -8.627430e+05
# 4             age_years -9.084673e+05
