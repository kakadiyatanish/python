# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("hospital_patients_1000_with_age.csv")
df.head()
# Out:
#    patient_id  first_name  last_name  gender date_of_birth  \
# 0           1     Kaitlin      Ortiz  female    2010-06-26
# 1           2      Tanner  Bashirian    male    2004-07-03
# 2           3  Clementine  Schroeder  female    1940-12-31
# 3           4      Zakary     Jacobs    male    1953-07-25
# 4           5     Sanford   Shanahan    male    1983-09-27
#
#                        email        phone        department  billing_amount  \
# 0  ortiz.jacinto@friesen.net  17855514628  General Medicine           21744
# 1            vveum@yahoo.com  19418681095       Orthopedics           47015
# 2    sauer.vicente@yahoo.com  18312295379  General Medicine           25753
# 3        alexane55@yahoo.com  12157567675        Pediatrics           24127
# 4     shanahan.flo@yahoo.com  15852518336        Pediatrics           41691
#
#   admission_date discharge_date  Age
# 0     2026-01-15     2026-01-17   52
# 1     2025-12-29     2026-01-08   15
# 2     2026-01-11     2026-01-19   72
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      1000 non-null   int64
#  1   first_name      1000 non-null   object
#  2   last_name       1000 non-null   object
#  3   gender          1000 non-null   object
#  4   date_of_birth   1000 non-null   object
#  5   email           1000 non-null   object
#  6   phone           1000 non-null   int64
#  7   department      1000 non-null   object
#  8   billing_amount  1000 non-null   int64
#  9   admission_date  1000 non-null   object
#  10  discharge_date  1000 non-null   object
#  11  Age             1000 non-null   int64
# dtypes: int64(4), object(8)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#         patient_id         phone  billing_amount          Age
# count  1000.000000  1.000000e+03     1000.000000  1000.000000
# mean    500.500000  1.594694e+10    27573.833000    44.271000
# std     288.819436  2.319047e+09    13077.565128    26.364914
# min       1.000000  1.201286e+10     5017.000000     1.000000
# 25%     250.750000  1.385771e+10    15684.000000    21.000000
# 50%     500.500000  1.585821e+10    27613.500000    45.000000
# 75%     750.250000  1.801241e+10    39153.250000    65.000000
# max    1000.000000  1.989919e+10    49994.000000    90.000000

# %%
df.isnull().sum()
# Out:
# patient_id        0
# first_name        0
# last_name         0
# gender            0
# date_of_birth     0
# email             0
# phone             0
# department        0
# billing_amount    0
# admission_date    0
# discharge_date    0
# Age               0
# dtype: int64

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df.dtypes
# Out:
# patient_id         int64
# first_name        object
# last_name         object
# gender            object
# date_of_birth     object
# email             object
# phone              int64
# department        object
# billing_amount     int64
# admission_date    object
# discharge_date    object
# Age                int64
# dtype: object

# %% [markdown]
# # Univariate Analysis

# %%
sns.histplot(df['patient_id'], kde=True)
plt.title('distribution of patient ids')
plt.show()

# %% [markdown]
# The plot shows that patient IDs are evenly distributed across the range.
# Since patient_id is an identifier, this distribution has no analytical meaning.

# %%
sns.histplot(df['Age'], kde=True)
plt.title('patient age')
plt.show()

# %% [markdown]
# The plot shows how patient ages are distributed across different age groups.
# Ages are spread widely, with some peaks indicating more patients in certain age ranges.

# %%
sns.histplot(df['billing_amount'], kde=True)
plt.title('distribution of billing amount')
plt.show()

# %% [markdown]
# The plot shows the distribution of billing amounts across patients.
# Billing values are spread over a wide range with mild peaks, indicating variability in charges.

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                 patient_id     phone  billing_amount       Age
# patient_id        1.000000 -0.025242       -0.036994 -0.016942
# phone            -0.025242  1.000000        0.020001 -0.001138
# billing_amount   -0.036994  0.020001        1.000000  0.004651
# Age              -0.016942 -0.001138        0.004651  1.000000

# %% [markdown]
# The correlation matrix shows very weak or near-zero relationships between all variables.
# This indicates no strong linear correlation between age, billing amount, patient ID, and phone.

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# The heatmap visualizes correlations between variables and shows all values are close to zero.
# This confirms there is no strong linear relationship among age, billing amount, patient ID, and phone.
